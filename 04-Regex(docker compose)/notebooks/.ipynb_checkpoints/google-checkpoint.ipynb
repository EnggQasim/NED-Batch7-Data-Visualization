# %% [markdown]
# # google search

# %%
with open("view-source:https://www.google.com/search?q=pakistan&rlz=1C5CHFA_enPK1068PK1068&oq=pakistan&gs_lcrp=EgZjaHJvbWUqBwgAEAAYjwIyBwgAEAAYjwIyEggBEC4YQxiDARixAxiABBiKBTIGCAIQRRg7MhMIAxAuGIMBGMcBGLEDGNEDGIAEMgYIBBBFGDwyBggFEEUYQTIGCAYQRRhBMgYIBxBFGEHSAQgxMzA3ajBqN6gCALACAA&sourceid=chrome&ie=UTF-8") as file:
    data = file.read()
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 with open("view-source:https://www.google.com/search?q=pakistan&rlz=1C5CHFA_enPK1068PK1068&oq=pakistan&gs_lcrp=EgZjaHJvbWUqBwgAEAAYjwIyBwgAEAAYjwIyEggBEC4YQxiDARixAxiABBiKBTIGCAIQRRg7MhMIAxAuGIMBGMcBGLEDGNEDGIAEMgYIBBBFGDwyBggFEEUYQTIGCAYQRRhBMgYIBxBFGEHSAQgxMzA3ajBqN6gCALACAA&sourceid=chrome&ie=UTF-8") as file:
#       2     data = file.read()
#       3 data
#
# File /opt/conda/lib/python3.11/site-packages/IPython/core/interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# ...

# %%
import requests

data = requests.get("https://www.google.com/search?q=pakistan&rlz=1C5CHFA_enPK1068PK1068&oq=pakistan&gs_lcrp=EgZjaHJvbWUqBwgAEAAYjwIyBwgAEAAYjwIyEggBEC4YQxiDARixAxiABBiKBTIGCAIQRRg7MhMIAxAuGIMBGMcBGLEDGNEDGIAEMgYIBBBFGDwyBggFEEUYQTIGCAYQRRhBMgYIBxBFGEHSAQgxMzA3ajBqN6gCALACAA&sourceid=chrome&ie=UTF-8")
data
# Out:
# <Response [200]>

# %%
data.text
# Out:
# '<!doctype html><html lang="en-PK"><head><meta charset="UTF-8"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>pakistan - Google Search</title><script nonce="qiPyPJWb6FVRJXDwjoQKhA">window._hst=Date.now();performance&&performance.mark&&performance.mark("SearchHeadStart");</script><script nonce="qiPyPJWb6FVRJXDwjoQKhA">(function(){\ndocument.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a=c==="1"||c==="q"&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if(a.tagName==="A"){a=a.getAttribute("data-nohref")==="1";break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){window.google=window.google||{};var a=window.performance&&window.performance.timing&&"navigationStart"in window.performan
# ...
